# %%
<!-- Filtro para selección todos los Tiddler con el tag 'Decision' -->
<$list filter="[all[current]tag[Decision]]">
  <div class="tw-costs-edit-fields" style="margin-top: 1em; padding: 0.5em; border-left: 4px solid #ccc;">

    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
          <label style="width: 180px; color: #FF5733;"><strong>Decisional Process:</strong></label>
        <$select tiddler=<<currentTiddler>> field="decisionalProcess" default="">
          <style> select option[value="solution"] {color: grey;}
          select option[value="indicator"] {color: purple;}
          select option[value="positiveImpact"] {color: green;}
          select option[value="negativeImpact"] {color: red;}</style>
          <option value="">-none-</option>
          <option value="strength">Strength</option>
          <option value="weakness">Weakness</option>
          <option value="threat">Threat</option>
          <option value="opportunity">Opportunity</option>
          <option value="solution">Solution</option>
          <option value="indicator">Indicator</option>
          <option value="positiveImpact">Impact(Positive)</option>
          <option value="negativeImpact">Impact(Negative)</option>
        </$select>
      </div>
      
    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
          <label style="width: 180px;"><strong>Concerned Domain:</strong></label>
          <$select tiddler=<<currentTiddler>> field="concernedDomain" style="flex: 1;">
            <option disabled>Choose an option</option>
            <option value="">-none-</option>
            <option value="cultural">cultural</option>
            <option value="housing">housing</option>
            <option value="urbanism">urbanism</option>
            <option value="environmental">environmental</option>
            <option value="energy">energy</option>
            <option value="social">social</option>
            <option value="emotional">emotional</option>
            <option value="working environment">working environment</option>
            <option value="tourism & leisure">tourism & leisure</option>
            <option value="health">health</option>
            <option value="welfare state">welfare state</option>
            <option value="food">food</option>
            <option value="territorial development">territorial development</option>
            <option value="risk management">risk management</option>
            <option value="water manegement">water manegement</option>
            <option value="hydrogeology">hydrogeology</option>
            <option value="multiple">multiple</option>
            <option value="other">other</option>
          </$select>
        </div>

    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
      <label style="width: 180px;"><strong>Decision Type:</strong></label>
      <$select tiddler=<<currentTiddler>> field="decisionType" style="flex: 1;">
        <option disabled>Choose an option</option>
        <option value="">-none-</option>
        <option value="solution">solution</option>
        <option value="project">project</option>
        <option value="program">program</option>
        <option value="plan">plan</option>
        <option value="policy">policy</option>
        <option value="rule">rule</option>
        <option value="other">other</option>
      </$select>
    </div>


    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
      <label style="width: 180px;"><strong>Affected Time Period:</strong></label>
      <$select tiddler=<<currentTiddler>> field="affectedTimePeriod" style="flex: 1;">
        <option disabled>Choose an option</option>
        <option value="">-none-</option>
        <option value="endless">endless</option>
        <option value="1 century or more">1 century or more</option>
        <option value="1 decade or more">1 decade or more</option>
        <option value="1 year or more">1 year or more</option>
        <option value="1 month or more">1 month or more</option>
        <option value="1 week or more">1 week or more</option>
        <option value="1 day or more">1 day or more</option>
        <option value="1 hour or more">1 hour or more</option>
        <option value="1 minute or more">1 minute or more</option>
        <option value="instantaneous">instantaneous</option>
        <option value="other">other</option>
      </$select>
    </div>

    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
      <label style="width: 180px;"><strong>deadline:</strong></label>
      <$edit-text field="deadline" tag="input" type="date" style="flex: 1;" />
    </div>

    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
      <label style="width: 180px;"><strong>Regulated:</strong></label>
      <$select tiddler=<<currentTiddler>> field="regulated" style="flex: 1;">
        <option disabled>Choose an option</option>
        <option value="Yes">Yes</option>
        <option value="No">No</option>
      </$select>
    </div>

    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
      <label style="width: 180px;"><strong>Status Development:</strong></label>
      <$select tiddler=<<currentTiddler>> field="statusDevelopment" style="flex: 1;">
        <option disabled>Choose an option</option>
        <option value="">-none-</option>
        <option value="proposed">proposed</option>
        <option value="under discussion">under discussion</option>
        <option value="planned">planned</option>
        <option value="accepted">accepted</option>
        <option value="implemented">implemented</option>
        <option value="in progress">in progress</option>
        <option value="executed">executed</option>
        <option value="disabled">disabled</option>
        <option value="other">other</option>
      </$select>
    </div>

    <div style="display: flex; align-items: center; margin-bottom: 0.5em;">
      <label style="width: 180px;"><strong>Comments:</strong></label>
      <$edit-text field="Comments" tag="textarea" rows="8" style="width: 100%; font-size: 1.1em; padding: 0.5em;" />
    </div>

  </div>
</$list>
