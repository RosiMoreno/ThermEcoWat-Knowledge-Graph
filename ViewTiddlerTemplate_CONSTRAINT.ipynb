# %%
 <div class="tw-costs-fields" style="margin-top: 1em; padding: 0.5em; border-top: 1px solid #ccc;">
    <p><strong style="color: #FF5733; ">Decisional Process:</strong> <$view field="decisionalProcess"/></p>
    <p><strong>Concerned Domain:</strong> <$view field="concernedDomain"/></p>
    <p><strong>Regulated:</strong> <$view field="regulated"/></p>
    <p><strong>Reversibility:</strong> <$view field="reversibility"/></p>
    <p><strong>Tangible:</strong> <$view field="tangible"/></p>
    <p><strong>Affected Time Period:</strong> <$view field="affectedTimePeriod"/></p>
    <p><strong>Document of Reference:</strong> <$view field="documentOfReference"/></p>
    <p><strong>Status Development:</strong> <$view field="statusDevelopment"/></p>
    <p><strong>Comments:</strong> <$view field="Comments"/></p>
  </div>
